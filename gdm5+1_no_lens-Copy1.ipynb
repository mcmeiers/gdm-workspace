# %%
# Show plots inline, and load main getdist plot module and samples class
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'..')))
from getdist import plots, MCSamples
import getdist
import matplotlib.pyplot as plt
import IPython
print('GetDist Version: %s, Matplotlib version: %s'%(getdist.__version__, plt.matplotlib.__version__))
# matplotlib 2 may not work very well without usetex on, can uncomment
# plt.rcParams['text.usetex']=True
# Out:
# GetDist Version: 1.3.3, Matplotlib version: 3.5.1

# %%
GDM_DATA_PATH = '/global/cscratch1/sd/mcmeiers/gdm6/gdm_6_no_lensing/data'
PLA_DATA_PATH = '/global/cscratch1/sd/mcmeiers/pla_data/base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE'
gdm_samples = loadMCSamples(GDM_DATA_PATH, settings={'ignore_rows':0.3})
pla_samples = loadMCSamples(PLA_DATA_PATH, settings={'ignore_rows':0.3})
# Out:
# /global/cscratch1/sd/mcmeiers/gdm6/gdm_6_no_lensing/data.4.txt
# /global/cscratch1/sd/mcmeiers/gdm6/gdm_6_no_lensing/data.3.txt
# /global/cscratch1/sd/mcmeiers/gdm6/gdm_6_no_lensing/data.2.txt
# /global/cscratch1/sd/mcmeiers/gdm6/gdm_6_no_lensing/data.1.txt
# Removed 0.3 as burn in
# /global/cscratch1/sd/mcmeiers/pla_data/base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_1.txt
# /global/cscratch1/sd/mcmeiers/pla_data/base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_4.txt
# /global/cscratch1/sd/mcmeiers/pla_data/base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_2.txt
# /global/cscratch1/sd/mcmeiers/pla_data/base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_3.txt
# Removed no burn in

# %%
pla_p = pla_samples.getParams()
pla_samples.addDerived(pla_p.H0/100, name='h', label='h')

# %%
g = plots.get_subplot_plotter()
g.triangle_plot([gdm_samples,pla_samples], ['omega_cdm','omega_b','h', 'gdm_alpha','w_0','w_1','w_2','w_3','w_4'],filled=True)
# Out:
# WARNING:root:auto bandwidth for w_4 very small or failed (h=0.00011294391819278643,N_eff=279.502185541298). Using fallback (h=0.12607967971495868)
